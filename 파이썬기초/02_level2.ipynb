# %% [markdown]
# ---
#
#
# # 실습과제 1: 사칙연산 미니 계산기
#
# ---
#
#
# ## 🎯 목표
#
# - 사용자로부터 숫자를 입력받아 사칙연산 계산기를 만들어봅니다.
#
# - 입력값을 int()로 정수형으로 변환합니다.
#
# - 산술 연산자(+, -, *, /)를 사용합니다.
#
# - 조건문(if / elif / else)으로 어떤 연산을 수행할지 분기합니다.
#
# - f-string을 활용해 결과를 보기 좋게 출력합니다.

# %%
# TODO: 사용자로부터 첫 번째 숫자를 입력받으세요

num1 = int(input("첫번째 숫자를 입력하세요 : "))

# TODO: 사용자로부터 두 번째 숫자를 입력받으세요
num2 = int(input("두번째 숫자를 입력하세요 : "))

# TODO: 연산자(+,-,*,/)를 입력받으세요
operator = input("연산자(+,-,*,/)를 입력하세요 : ")

# TODO: 조건문(if/elif/else)으로 연산을 수행하세요

if operator == '+' :
    print(f"{num1}{operator}{num2} = {num1+num2}")
elif operator == '-' :
    print(f"{num1}{operator}{num2} = {num1-num2}")
elif operator == '*' :
    print(f"{num1}{operator}{num2} = {num1*num2}")
elif operator == '/' :
    print(f"{num1}{operator}{num2} = {num1/num2:.2f}")
else : 
    print("4가지 연산자만 계산 가능합니다.")

# TODO: f-string을 사용하여 결과를 출력하세요
# Out:
# 첫번째 숫자를 입력하세요 :  2
# 두번째 숫자를 입력하세요 :  34
# 연산자(+,-,*,/)를 입력하세요 :  g
# 4가지 연산자만 계산 가능합니다.

# %% [markdown]
# ---
#
#
# # 실습과제 2: 온도 단위 변환기
#
# ---
#
#
# ## 🎯 목표
#
# - 사용자로부터 길이와 온도를 입력받아 단위를 변환해봅니다.
#
# - 센티미터 → 미터로 길이를 변환합니다.
#
# - **섭씨(℃) → 화씨(℉)**로 온도를 변환합니다.
#
# - 입력값은 float()로 실수형으로 변환합니다.
#
# - 변환 결과는 f-string을 이용해 보기 좋게 출력합니다.

# %%
# TODO: 사용자로부터 cm 값을 입력받으세요

cm = float(input("센티미터(Cm) 값을 입력하세요 : "))
celsius = float(input("섭씨(℃) 값을 입력하세요 : "))

# TODO: cm → m 변환 기능을 작성하세요

'''
섭씨 온도에 1.8(또는 9/5)을 곱합니다.
그 결과값에 32를 더합니다.
'''

meter = cm / 100
fahrenheit = (celsius * 9/5) + 32

print(f"{cm:.2f} cm는 {meter:.2f} m 입니다.")
print(f"{celsius:.2f} ℃는 {fahrenheit:.2f} ℉ 입니다.")

# TODO: 변환 결과를 출력하세요

# TODO: 사용자로부터 섭씨(℃) 값을 입력받으세요

# TODO: 섭씨 → 화씨 변환 기능을 작성하세요

# TODO: 변환 결과를 출력하세요
# Out:
# 센티미터(Cm) 값을 입력하세요 :  243
# 섭씨(℃) 값을 입력하세요 :  22
# 243.00 cm는 2.43 m 입니다.
# 22.00 ℃는 71.60 ℉ 입니다.
