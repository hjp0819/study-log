# %%
def check_temp(tmp):
    if tmp < 36.5:
        return f"{tmp}℃ ⚠️ 낮은 체온입니다."
    elif tmp < 37.5:
        return f"{tmp}℃ ✅ 정상입니다."
    elif tmp < 38.0:
        return f"{tmp}℃ 🤒 미열입니다."
    else:
        return f"{tmp}℃ 🔥 고열입니다."

tmp = float(input("체온을 입력하세요 : "))
check_temp(tmp)
# Out:
# 체온을 입력하세요 :  36.5
# '36.5℃ ✅ 정상입니다.'

# %%
def check_temp(tmp):
    if tmp < 36.5:
        return f"{tmp}℃ ⚠️ 낮은 체온입니다."
    elif tmp < 37.5:
        return f"{tmp}℃ ✅ 정상입니다."
    elif tmp < 38.0:
        return f"{tmp}℃ 🤒 미열입니다."
    else:
        return f"{tmp}℃ 🔥 고열입니다."

# 입력받기
temps_str = input("체온들을 입력하세요 (공백으로 구분): ").split()

# 문자열 → float 변환
temps = []
for s in temps_str:
    temps.append(float(s))

# 결과 출력
for t in temps:
    print(check_temp(t))
# Out:
# 체온들을 입력하세요 (공백으로 구분):  36.5 37.5 38.2 39
# 36.5℃ ✅ 정상입니다.
# 37.5℃ 🤒 미열입니다.
# 38.2℃ 🔥 고열입니다.
# 39.0℃ 🔥 고열입니다.

# %%
def check_temp(tmp):
    if tmp < 36.5:
        return f"{tmp}℃ ⚠️ 낮은 체온입니다."
    elif tmp < 37.5:
        return f"{tmp}℃ ✅ 정상입니다."
    elif tmp < 38.0:
        return f"{tmp}℃ 🤒 미열입니다."
    else:
        return f"{tmp}℃ 🔥 고열입니다."

# 여러 개 체온 입력받기
temps = list(map(float, input("체온들을 입력하세요 (공백으로 구분): ").split()))

# 결과 출력
for t in temps:
    print(check_temp(t))
# Out:
# 체온들을 입력하세요 (공백으로 구분):  36.5 32.7 38.2
# 36.5℃ ✅ 정상입니다.
# 32.7℃ ⚠️ 낮은 체온입니다.
# 38.2℃ 🔥 고열입니다.

# %%
def check_bp(bp) :
    if bp<0 or bp>=300 :
        bp_chk = "무효/재입력필요"
    elif bp<120 :
        bp_chk = "정상"
    elif bp<140 :
        bp_chk = "주의"
    else:
        bp_chk = "위험"
    return bp_chk

def check_bg(bg) :
    if bg<0 or bg>=300 :
        bg_chk = "무효/재입력필요"
    elif bg<100 :
        bg_chk = "정상"
    elif bg<126 :
        bg_chk = "주의"
    else:
        bg_chk = "위험"
    return bg_chk

#입력받기
td = input("날짜를 입력하세요 (예:2025-09-09) :")
bp = int(input("혈압을 입력하세요 :"))
bg = int(input("혈당을 입력하세요 : "))

bp_chk = check_bp(bp)
bg_chk = check_bg(bg)

print(f"[{td}] 혈압 : {bp} ({bp_chk}), 혈당 : {bg} ({bg_chk})")
# Out:
# 날짜를 입력하세요 (예:2025-09-09) : 2025-09-09
# 혈압을 입력하세요 : 140
# 혈당을 입력하세요 :  155
# [2025-09-09 혈압 : 140 (위험), 혈당 : 140 (위험)

# %%
def check_bp(bp) :
    if bp<0 or bp>=300 :
        bp_chk = "무효/재입력필요"
    elif bp<120 :
        bp_chk = "정상"
    elif bp<140 :
        bp_chk = "주의"
    else:
        bp_chk = "위험"
    return bp_chk

bplist = list(map(int, input("혈압들을 입력하세요 (공백으로 구분): ").split()))

risk_bps = list(filter(lambda bp:check_bp(bp)=="위험", bplist))

print(f"위험 혈압 리스트:{risk_bps}")
# Out:
# 혈압들을 입력하세요 (공백으로 구분):  121 156 166 121 110 135
# 위험 혈압 리스트:[156, 166]

# %%
dates = input("날짜들을 입력하세요(공백 구분, YYYY-MM-DD):").split()
bplist = list(map(int, input("혈압들을 입력하세요(공백 구분):").split()))

dbp = zip(dates, bplist) 

for d, bp in dbp :
    print(f"{d}: {bp}")
# Out:
# 날짜들을 입력하세요(공백 구분, YYYY-MM-DD): 2025-09-09 2025-09-10 2025-09-11
# 혈압들을 입력하세요(공백 구분): 135 118 145
# 2025-09-09: 135
# 2025-09-10: 118
# 2025-09-11: 145
