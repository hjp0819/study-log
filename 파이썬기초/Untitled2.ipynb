# %%
import numpy as np

weight_kg = [71, 85.8, 61.0, 81.2]

weight_kg_np = np.array(weight_kg)

print(weight_kg_np)
# Out:
# [71.  85.8 61.  81.2]

# %%
import sys, numpy as np
print("PYTHON:", sys.executable)
print("NUMPY :", np.__version__)
# Out:
# PYTHON: C:\Users\USER\anaconda3\envs\myenv\python.exe
# NUMPY : 2.0.1
